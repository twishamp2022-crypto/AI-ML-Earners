# %% [markdown]
# <a href="https://colab.research.google.com/github/twishamp2022-crypto/AI-ML-Earners/blob/main/earners_ai_ml_1_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Earners AI ML by Aditya Jain Sir lecture 1.10

# %%
for i in range(5):
    for j in range(6,10):
        print(i,j)
# Out:
# 0 6
# 0 7
# 0 8
# 0 9
# 1 6
# 1 7
# 1 8
# 1 9
# 2 6
# 2 7
# 2 8
# 2 9
# 3 6
# 3 7
# 3 8
# 3 9
# 4 6
# 4 7
# 4 8
# 4 9

# %% [markdown]
# ## What is the output?
# ```python
# for i in range(2):
#     for j in range(2):
#         print(j, end=" ")
#     print()
# ```
#
# A.
# ```
# 0 1
# 0 1
# ```
# B.
# ```
# 12
# 12
# ```
#
# C.
# ```
# 0
# 1
# ```
# D. `Error`
#
# ---
#
# > Ans: A

# %% [markdown]
# Which pattern will this code print?
# ```python
# for row in range(4):
#     for col in range(4):
#         print("#", end=" ")
#     print()
# ```
#
# A.
# ```
# #
# ##
# ###
# ####
# ```
#
# B.
# ```
# # # # #
#
# # # # #
#
# # # # #
#
# # # # #
# ```
#
# C.
# ```
# ####
# ####
# ####
# ####
# ```
#
# D.
# ```
# #
# #
# #
# #
# ```
#
# ---
# > Ans: B

# %% [markdown]
# # What is the output?
#
# ```python
# for i in range(1,3):
#     for j in range(1,3):
#         print(i + j, end=" ")
#     print()
# ```
#
# A.
# ```
# 2 3
# 3 4
# ```
# B.
# ```
# 1 2
# 2 3
# ```
# C.
# ```
# 24
# 46
# ```
# D.
# ```
# 35
# ```
# -----
# > Ans: D

# %%
for i in range(1,3):
    for j in range(1,3):
        print(i,j,i + j)
    print()
# Out:
# 1 1 2
# 1 2 3
#
# 2 1 3
# 2 2 4

# %% [markdown]
# # List

# %%
m1 = 90
m2 = 86
m3 = 95
m4 = 83
m5 = 70

# %%
marks = [90, 86, 95, 83, 70]

# %%
print(marks)
# Out:
# [90, 86, 95, 83, 70]

# %%
a = [45, "AJ", 6.8, True]

# %%
print(a)
# Out:
# [45, 'AJ', 6.8, True]

# %%
type(a)
# Out:
# list

# %%
type(marks)
# Out:
# list

# %%
students = []
print(students)
# Out:
# []

# %% [markdown]
# # Indexing

# %%
#indexing starts with 0

# %%
print(marks)
# Out:
# [90, 86, 95, 83, 70]

# %%
marks[0]
# Out:
# 90

# %%
marks[2]
# Out:
# 95

# %%
n = len(marks)

# %%
print(n)
# Out:
# 5

# %%
marks[n-1]
# Out:
# 70

# %%
marks[-1]
# Out:
# 70

# %%
marks[-2]
# Out:
# 83

# %%
marks[n-2]
# Out:
# 83

# %%
marks[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1800/2760646083.py in <cell line: 0>()
# ----> 1 marks[5]
#
# IndexError: list index out of range

# %%
marks
# Out:
# [90, 86, 95, 83, 70]

# %%
marks[2]
# Out:
# 95

# %%
marks[-3]
# Out:
# 95

# %%
marks[2:3]
# Out:
# [95]

# %% [markdown]
# # Iterating over a loop

# %%
for _ in range(len(marks)):
    print(marks[i])
# Out:
# 95
# 95
# 95
# 95
# 95

# %%
for ele in marks:
    print(ele)
# Out:
# 90
# 86
# 95
# 83
# 70

# %%
marks
# Out:
# [90, 86, 95, 83, 70]

# %%
# write a code to print the elements at even indexes

i=0
for ele in marks:
    if not i%2:
        print(ele)
    i+=1
# Out:
# 90
# 95
# 70

# %%
# write a code to print all even elements

for _ in marks:
    if not _%2:
        print(_)
# Out:
# 90
# 86
# 70

# %%
for _ in range(len(marks)):
    if not marks[_]%2:
        print(marks[_])
    i+=1
# Out:
# 90
# 86
# 70

# %% [markdown]
# # Quiz

# %% [markdown]
# ## What is the output?
#
# ```python
# numbers= [10,20,30]
# print(numbers[0])
# ```

# %% [markdown]
# # What is the output?
# ```python
# fruits = ["Apple", "Banana","Mango"]
# print(fruits[-1])
# ```

# %% [markdown]
# ## What is the output?
# ```python
# marks = [70,80,90]
# print(len(marks))
# ```

# %% [markdown]
# # Which of the following is a valid Python list?
#
# A.
# ```
# marks = (10,20,30)
# ```
# B.
# ```
# marks = {10,20,30}
# ```
# C.
# ```
# marks = [10,20,30]
# ```
# D.
# ```
# marks = <10,20,30>
# ```
#
# ----
# > Ans: D.
# ```
# marks = <10,20,30>
# ```

# %% [markdown]
# # What is the output?
# ```python
# numbers = [5,10,15,20]
# print(numbers[-2])
# ```

# %%
numbers = [5,10,15,20]
print(numbers[-2])
# Out:
# 15

# %%
# What is the output?

fruits = ["Apple","Banana","Mango"]

fruits[1] = "Orange"

print(fruits)
# Out:
# ['Apple', 'Orange', 'Mango']

# %%
# What is the output?

numbers = [10,20]
print(numbers[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1800/2681324005.py in <cell line: 0>()
#       2
#       3 numbers = [10,20]
# ----> 4 print(numbers[2])
#
# IndexError: list index out of range

# %%
# What is the output?

numbers = [1,2,3]

for num in numbers:
    print(num)
# Out:
# 1
# 2
# 3

# %%
# What is printed?
numbers = [5,10,15]

for i in range(len(numbers)):
    print(numbers[i])
# Out:
# 5
# 10
# 15

# %%
# What is the output?

marks = [60,70,80,90]
print(max(marks))
# Out:
# 90

# %%
# What is the output?

marks = [60,70,80,90]
print(min(marks))
# Out:
# 60

# %%
# Write a code to find the sum of all the elements of the list.
marks = [60,70,80,90]
sum(marks)
# Out:
# 300

# %%
# Write a code to find the average of all the elements of the list.
sum(marks)/len(marks)
# Out:
# 75.0

# %%
marks = [60,70,80,90]
n = len(marks)
sum = 0
for ele in marks:
    sum += ele
print(sum/n)
# Out:
# 75.0

# %%
# What is printed?

numbers = [9,5,7,1]

print(sorted(numbers))
# Out:
# [1, 5, 7, 9]

# %%
numbers
# Out:
# [1, 5, 7, 9]

# %%
numbers.sort()

# %%
numbers
# Out:
# [1, 5, 7, 9]

# %%
# What is the output?

names = ["A","B","C"]
print(names[len(names)-1])
# Out:
# C

# %%
numbers = [5, 10, 15]
print(numbers)
numbers[1] = numbers[0] + numbers[2]
print(numbers)
print(sum(numbers))
# Out:
# [5, 10, 15]
# [5, 20, 15]
# 40

# %%
marks = [50, 60, 70, 80]

for i in range(len(marks)):
    marks[i] = marks[i] + 5

print(marks)
# Out:
# [55, 65, 75, 85]

# %%
data = [2,4,6]

for i in range(len(data)):
    print(i, data[i])
# Out:
# 0 2
# 1 4
# 2 6

# %%
numbers = [8, 2, 5,1]

print(min(numbers))

print(max(numbers))

print(max(numbers) - min(numbers))
# Out:
# 1
# 8
# 7

# %%
numbers = [10, 20, 30]

print(numbers[-1])

numbers[-1] = 100

print(numbers)
# Out:
# 30
# [10, 20, 100]

# %%
nums = [2, 4, 6, 8]

count = 0

for n in nums:
    if n > 4:
        count +=1
print(count)
# Out:
# 2

# %%
marks = [80, 75, 90]

highest = max(marks)

for m in marks:
    print(highest - m)
# Out:
# 10
# 15
# 0

# %%
numbers = [3,5,7]

result = 1

for n in numbers:
    result = result * n

print(result)
# Out:
# 105
