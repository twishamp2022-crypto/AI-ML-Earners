# %% [markdown]
# <a href="https://colab.research.google.com/github/twishamp2022-crypto/AI-ML-Earners/blob/main/earners_ai_ml_1_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student = ["Rahul", 22, 91.5, "Nagpur"]

# %%
student = {
    "name": "Rahul",
    "age": 22,
    "CGPA": 91.5,
    "city": "Nagpur"
}

# %%
student
# Out:
# {'name': 'Rahul', 'age': 22, 'CGPA': 91.5, 'city': 'Nagpur'}

# %%
type(student)
# Out:
# dict

# %%
student["name"]
# Out:
# 'Rahul'

# %%
student["CGPA"]
# Out:
# 91.5

# %%
student["city"]
# Out:
# 'Nagpur'

# %%
print(student)
# Out:
# {'name': 'Rahul', 'age': 22, 'CGPA': 91.5, 'city': 'Nagpur'}

# %%
from pprint import pprint
pprint(student)
# Out:
# {'CGPA': 91.5, 'age': 22, 'city': 'Nagpur', 'name': 'Rahul'}

# %%
student["state"] = "Maharastra"

# %%
student
# Out:
# {'name': 'Rahul',
#  'age': 22,
#  'CGPA': 91.5,
#  'city': 'Nagpur',
#  'state': 'Maharastra'}

# %%
student["Age"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1419/2431116529.py in <cell line: 0>()
# ----> 1 student["Age"]
#
# KeyError: 'Age'

# %%
student["address"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1419/1757129455.py in <cell line: 0>()
# ----> 1 student["address"]
#
# KeyError: 'address'

# %%
student.get("age")
# Out:
# 22

# %%
student.get("address")

# %%
student.get("address", "Key not found!")
# Out:
# 'Key not found!'

# %%
student.get("age", "Key not found")
# Out:
# 22

# %%
student.pop("state")
# Out:
# 'Maharastra'

# %%
student
# Out:
# {'name': 'Rahul', 'age': 22, 'CGPA': 91.5, 'city': 'Nagpur'}

# %%
student.pop("state")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1419/2866018373.py in <cell line: 0>()
# ----> 1 student.pop("state")
#
# KeyError: 'state'

# %% [markdown]
# # Loop over Dictionaries

# %%
student
# Out:
# {'name': 'Rahul', 'age': 22, 'CGPA': 91.5, 'city': 'Nagpur'}

# %%
for k in student.keys():
    print(k)
# Out:
# name
# age
# CGPA
# city

# %%
for k in student.keys():
    print(student[k])
# Out:
# Rahul
# 22
# 91.5
# Nagpur

# %%
for k in student.values():
    print(k)
# Out:
# Rahul
# 22
# 91.5
# Nagpur

# %%
for _ in student.items():
    print(_)
# Out:
# ('name', 'Rahul')
# ('age', 22)
# ('CGPA', 91.5)
# ('city', 'Nagpur')

# %%
for _ in student.items():
    print("key=", _[0], ", value=",_[1])
# Out:
# key= name , value= Rahul
# key= age , value= 22
# key= CGPA , value= 91.5
# key= city , value= Nagpur

# %%
student = {
    "name": "Rahul",
    "age": 22
}

print(student["name"])
# Out:
# Rahul

# %% [markdown]
# Which of the following correctly creates a dictionary?
#
# A.
# ```python
# student = ["name":"Rahul"]
# ```
# B.
# ```python
# student = ("name":"Rahul")
# ```
# c.
# ```python
# student = {"name":"Rahul"}
# ```
# D.
# ```python
# student = <"name":"Rahul">
# ```
#
# ---
# > Ans: C.
# ```python
# student = {"name":"Rahul"}
# ```

# %%
student = {
    "name": "Rahul",
    "age": 22
}

student["age"] = 23

print(student)
# Out:
# {'name': 'Rahul', 'age': 23}

# %%
student = {
    "name": "Rahul",
    "age": 22
}
print(len(student))
# Out:
# 2

# %%
student = {
    "name":"Rahul"
}

print(student.get("city"))
# Out:
# None

# %%
student.get("city")

# %%
student = {
        "name":"Rahul"
}
print(student["city"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1419/1473464495.py in <cell line: 0>()
#       2         "name":"Rahul"
#       3 }
# ----> 4 print(student["city"])
#
# KeyError: 'city'

# %%
student = {
    "name":"Rahul",
    "age":22
}
print(student.keys())
# Out:
# dict_keys(['name', 'age'])

# %%
student = {
    "name":"Rahul",
    "age":22
}
print(student.values())
# Out:
# dict_values(['Rahul', 22])

# %%
student = {
    "name":"Rahul",
    "age": 22
}

for key in student:
    print(student[key])
# Out:
# Rahul
# 22

# %%
marks = {
"Math":90,
"Science":80,
"English":95

}

total = 0

for subject in marks:
    total += marks[subject]

print(total)
# Out:
# 265

# %%
cart = {
    "Milk":2,
    "Bread":1
}

cart["Eggs"] = 12

print(len(cart))
# Out:
# 3

# %%
employee = {
"salary":50000
}

employee["salary"] += 10000

print(employee["salary"])
# Out:
# 60000

# %%
student = {
    "name":"Rahul",
    "age":22
}

count = 0
for key in student.keys():
    count += 1
print(count)
# Out:
# 2

# %%
student = {
    "name": "Rahul",
    "age": 22
}

student["city"] = "Nagpur"
student["age"] += 1

print(student["age"])
# Out:
# 23

# %%
marks = {
    "Math": 90,
    "Science": 80,
    "English": 70
}

total = 0

for subject in marks.keys():
    total += marks[subject]

print(total / len(marks))
# Out:
# 80.0

# %%
data = {
    "A": 10,
    "B": 20,
    "C": 30
}

count = 0

for key in data.keys():
    if data[key] > 15:
        count += 1

print(count)
# Out:
# 2

# %%
student = {
    "name": "Rahul",
    "age": 22,
    "city": "Nagpur"
}

for key in student.keys():
    print(len(key))
# Out:
# 4
# 3
# 4
